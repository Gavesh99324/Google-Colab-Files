# %% [markdown]
# <a href="https://colab.research.google.com/github/Gavesh99324/Google-Colab-Files/blob/main/Data_Cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.listdir('/content/drive/MyDrive')
# Out:
# ['Getting started.pdf',
#  '9035923_2020.pdf',
#  '9035923_2020.gdoc',
#  'UNI 2.pdf',
#  'Document 10_1.jpg',
#  'IMG_20210612_171843.jpg',
#  'IMG_20210612_175242.jpg',
#  '6.jpg',
#  '11.jpg',
#  '9.jpg',
#  '5.jpg',
#  '4.jpg',
#  '8.jpg',
#  '2.jpg',
#  '10.jpg',
#  '3.jpg',
#  '1.jpg',
#  '7.jpg',
#  '13.jpg',
#  '12.jpg',
#  'University Application.pdf',
#  'IMG_20210612_164057.jpg',
#  '990841560V-PP (3).JPG.jpg',
#  '990841560V-NICF (3).JPG.jpg',
#  '990841560V-NICR (3).JPG.jpg',
#  '990841560V-PP (2).JPG.jpg',
#  '990841560V-NICF (2).JPG.jpg',
#  '990841560V-NICR (2).JPG.jpg',
#  '990841560V-PP (1).JPG.jpg',
#  '990841560V-NICF (1).JPG.jpg',
#  '990841560V-NICR (1).JPG.jpg',
#  '990841560V-PP.JPG.jpg',
#  '990841560V-NICF.JPG.jpg',
#  '990841560V-NICR.JPG.jpg',
#  'scan.pdf',
#  'Activity 1.docx',
#  '20APSE 4876',
#  '20APSE 4876.zip',
#  'IMG_1784.PNG',
#  '20APSE4876.pdf',
#  '20APSE4876 , QUIZ 02.pdf',
#  'IMG_1859.HEIC',
#  'IMG_2506.HEIC',
#  'IMG_2507.HEIC',
# ...

# %%
file_path="/content/drive/MyDrive/datamining_pratical1.csv"
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Student_ID       Name  Age Gender Department   GPA  Attendance  Projects  \
# 0           1  Student_1   24   Male         SE  3.70        76.0         0
# 1           2  Student_2   24   Male         DS  3.70        76.0         0
# 2           3  Student_3   22   Male         SE  2.90        50.0         3
# 3           4  Student_4   24   Male         DS  2.19        82.0         2
# 4           5  Student_5   20   Male         IT  3.14       100.0         5
#
#   Internship Graduated
# 0         No        No
# 1         No        No
# 2        Yes        No
# 3        Yes        No
# 4         No       Yes

# %%
df.shape
# Out:
# (50, 10)

# %%
df=df.dropna()

# %%
gender_mapping={'Male': 0, 'Female': 1}
df['Gender']=df['Gender'].map(gender_mapping)

# %%
df=df.rename(columns={'projects':'project'})

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 47 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  47 non-null     int64
#  1   Name        47 non-null     object
#  2   Age         47 non-null     int64
#  3   Gender      47 non-null     int64
#  4   Department  47 non-null     object
#  5   GPA         47 non-null     float64
#  6   Attendance  47 non-null     float64
#  7   Projects    47 non-null     int64
#  8   Internship  47 non-null     object
#  9   Graduated   47 non-null     object
# dtypes: float64(2), int64(4), object(4)
# memory usage: 4.0+ KB

# %%
file_path="/content/drive/MyDrive/datamining_pratical2.csv"
df=pd.read_csv(file_path)

# %%
df.head()
# Out:
#    Student_ID       Name  Age Gender Department   GPA  Attendance  Projects  \
# 0           1  Student_1   24   Male         SE  3.70        76.0         0
# 1           2  Student_2   24   Male         DS  3.70        76.0         0
# 2           3  Student_3   22   Male         SE  2.90        50.0         3
# 3           4  Student_4   24   Male         DS  2.19        82.0         2
# 4           5  Student_5   20   Male         IT  3.14       100.0         5
#
#   Internship Graduated
# 0         No        No
# 1         No        No
# 2        Yes        No
# 3        Yes        No
# 4         No       Yes

# %%
df.shape
# Out:
# (50, 10)

# %%
df.describe()
# Out:
#        Student_ID       Age        GPA   Attendance  Projects
# count    50.00000  50.00000  50.000000    47.000000   50.0000
# mean     25.50000  21.34000   3.001600   113.212766    1.9600
# std      14.57738   1.89101   0.548495   266.788463    1.5513
# min       1.00000  18.00000   2.000000    50.000000    0.0000
# 25%      13.25000  20.00000   2.542500    60.000000    0.2500
# 50%      25.50000  21.00000   3.120000    76.000000    2.0000
# 75%      37.75000  23.00000   3.397500    87.500000    3.0000
# max      50.00000  24.00000   3.940000  1900.000000    5.0000

# %%
df.loc[df['Attendance'] > 100, 'Attendance'] = np.nan
df
# Out:
#     Student_ID        Name  Age  Gender Department   GPA  Attendance  \
# 0            1   Student_1   24    Male         SE  3.70        76.0
# 1            2   Student_2   24    Male         DS  3.70        76.0
# 2            3   Student_3   22    Male         SE  2.90        50.0
# 3            4   Student_4   24    Male         DS  2.19        82.0
# 4            5   Student_5   20    Male         IT  3.14       100.0
# 5            6   Student_6   22    Male         SE  3.34         NaN
# 6            7   Student_7   22      Fe         DS  3.33        93.0
# 7            8   Student_8   24  Female         CS  3.18        73.0
# 8            9   Student_9   19    Male         IT  2.55        64.0
# 9           10  Student_10   20  Female         DS  3.12        81.0
# 10          11  Student_11   24  Female         CS  2.77        81.0
# 11          12  Student_12   20  Female         DS  3.94        73.0
# 12          13  Student_13   20  Female         CS  3.70        90.0
# ...

# %%
df['Attendance'] = df['Attendance'].fillna(df['Attendance'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  50 non-null     int64
#  1   Name        50 non-null     object
#  2   Age         50 non-null     int64
#  3   Gender      50 non-null     object
#  4   Department  50 non-null     object
#  5   GPA         50 non-null     float64
#  6   Attendance  50 non-null     float64
#  7   Projects    50 non-null     int64
#  8   Internship  50 non-null     object
#  9   Graduated   50 non-null     object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 4.0+ KB

# %%
df['Gender'] = df['Gender'].replace({'Ma': 'Male', 'Fe': 'Female'})
display(df.head())
# Out:
#    Student_ID       Name  Age Gender Department   GPA  Attendance  Projects  \
# 0           1  Student_1   24   Male         SE  3.70        76.0         0
# 1           2  Student_2   24   Male         DS  3.70        76.0         0
# 2           3  Student_3   22   Male         SE  2.90        50.0         3
# 3           4  Student_4   24   Male         DS  2.19        82.0         2
# 4           5  Student_5   20   Male         IT  3.14       100.0         5
#
#   Internship Graduated
# 0         No        No
# 1         No        No
# 2        Yes        No
# 3        Yes        No
# 4         No       Yes

# %%
df['Gender']=df['Gender'].replace({'male': 0, 'ma': 0, 'female': 1, 'fe': 1})

# %%
file_path="/content/drive/MyDrive/datamining_pratical2.csv"
df=pd.read_csv(file_path)

# Standardize 'Ma' to 'Male' and 'Fe' to 'Female', and convert to lowercase for consistent mapping
df['Gender'] = df['Gender'].replace({'Ma': 'Male', 'Fe': 'Female'})
df['Gender'] = df['Gender'].str.lower()

# Map standardized lowercase gender strings to numerical values
gender_mapping = {'male': 0, 'female': 1}
df['Gender'] = df['Gender'].map(gender_mapping)

print("Gender column standardized and encoded.")
display(df.head())
df.info()
# Out:
# Gender column standardized and encoded.
#    Student_ID       Name  Age  Gender Department   GPA  Attendance  Projects  \
# 0           1  Student_1   24       0         SE  3.70        76.0         0
# 1           2  Student_2   24       0         DS  3.70        76.0         0
# 2           3  Student_3   22       0         SE  2.90        50.0         3
# 3           4  Student_4   24       0         DS  2.19        82.0         2
# 4           5  Student_5   20       0         IT  3.14       100.0         5
#
#   Internship Graduated
# 0         No        No
# 1         No        No
# 2        Yes        No
# 3        Yes        No
# 4         No       Yes
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Student_ID  50 non-null     int64
#  1   Name        50 non-null     object
#  2   Age         50 non-null     int64
# ...

# %%
df
# Out:
#     Student_ID        Name  Age  Gender Department   GPA  Attendance  \
# 0            1   Student_1   24       0         SE  3.70        76.0
# 1            2   Student_2   24       0         DS  3.70        76.0
# 2            3   Student_3   22       0         SE  2.90        50.0
# 3            4   Student_4   24       0         DS  2.19        82.0
# 4            5   Student_5   20       0         IT  3.14       100.0
# 5            6   Student_6   22       0         SE  3.34      1900.0
# 6            7   Student_7   22       1         DS  3.33        93.0
# 7            8   Student_8   24       1         CS  3.18        73.0
# 8            9   Student_9   19       0         IT  2.55        64.0
# 9           10  Student_10   20       1         DS  3.12        81.0
# 10          11  Student_11   24       1         CS  2.77        81.0
# 11          12  Student_12   20       1         DS  3.94        73.0
# 12          13  Student_13   20       1         CS  3.70        90.0
# ...

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#     Student_ID        Name  Age  Gender Department   GPA  Attendance  \
# 0            1   Student_1   24       0         SE  3.70        76.0
# 1            2   Student_2   24       0         DS  3.70        76.0
# 2            3   Student_3   22       0         SE  2.90        50.0
# 3            4   Student_4   24       0         DS  2.19        82.0
# 4            5   Student_5   20       0         IT  3.14       100.0
# 5            6   Student_6   22       0         SE  3.34      1900.0
# 6            7   Student_7   22       1         DS  3.33        93.0
# 7            8   Student_8   24       1         CS  3.18        73.0
# 8            9   Student_9   19       0         IT  2.55        64.0
# 9           10  Student_10   20       1         DS  3.12        81.0
# 10          11  Student_11   24       1         CS  2.77        81.0
# 11          12  Student_12   20       1         DS  3.94        73.0
# 12          13  Student_13   20       1         CS  3.70        90.0
# ...
